# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# jonas_florian            /home/epool08/.conda/envs/jonas_florian
# base                     /opt/practical_course/miniconda3
# course                *  /opt/practical_course/miniconda3/envs/course

# %%
import clip
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10571/3143522045.py in <module>
# ----> 1 import clip
#
# ModuleNotFoundError: No module named 'clip'

# %%
# !pip list
# Out:
# Package             Version
# ------------------- ---------
# addict              2.4.0
# alembic             1.7.5
# anyio               2.2.0
# argon2-cffi         20.1.0
# async-generator     1.10
# attrs               21.4.0
# Babel               2.9.1
# backcall            0.2.0
# bleach              4.1.0
# blinker             1.4
# brotlipy            0.7.0
# certifi             2021.10.8
# certipy             0.1.3
# cffi                1.15.0
# charset-normalizer  2.0.4
# clip                1.0
# cloudpickle         2.0.0
# cryptography        3.4.8
# cycler              0.11.0
# cytoolz             0.11.0
# dask                2022.2.1
# debugpy             1.5.1
# decorator           5.1.0
# defusedxml          0.7.1
# deprecation         2.1.0
# entrypoints         0.3
# fastprogress        1.0.2
# fonttools           4.29.0
# fsspec              2022.2.0
# ftfy                6.1.1
# greenlet            1.1.1
# idna                3.3
# imagecodecs         2021.8.26
# ...
